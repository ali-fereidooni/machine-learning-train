# %% [markdown]
# ## MatPlotLib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3,4], [5,6,8,9])
plt.ylabel('funny numbers')
plt.show()

# %%
plt.plot([1,3,4,9], [-1,8,1,2], 'r+')

# %%
t = np.arange(0, 5, 0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g-.')
# Out:
# [<matplotlib.lines.Line2D at 0x14c859f6710>,
#  <matplotlib.lines.Line2D at 0x14c85a06610>,
#  <matplotlib.lines.Line2D at 0x14c85a58390>]

# %%
data = {
    'a' : np.arange(50),
    'b' : np.random.randint(0, 50, 50),
    'c' : np.random.randn(500)
}

# %%
plt.scatter(data['a'], data['c'])

# %%
plt.scatter(data['a'], data['b'])

# %% [markdown]
# # The end
